# %%
import numpy as np
import pandas as pd

df_patient=pd.read_csv("patient_details.csv")
df_medical=pd.read_csv("medical_records.csv")

df_patient.info()
df_medical.info()

df_patient.loc[df_patient['age']<0,'age']=np.nan
df_patient['age'].fillna(df_patient['age'].median(),inplace=True)
pd.set_option('display.max_rows', None)

df_patient['name'].fillna("Avaish",inplace=True)
df_patient.drop_duplicates(subset = 'patient_id', keep='first', inplace=True)

df_patient['gender']=df_patient['gender'].replace(
    {'m':'Male',
     'M':'Male',
     'f':'Female',
     'F':'Female'})

df_patient['city']=df_patient['city'].replace(
    {'mumbai':'Mumbai',
     'kolkata':'Kolkata'})

df_patient['height_cm']=pd.to_numeric(df_patient['height_cm'],errors='coerce')
df_patient.loc[df_patient['height_cm']<0,'height_cm']=np.nan
df_patient['height_cm'].fillna(df_patient['height_cm'].median(),inplace=True)

df_patient['admission_date'] = pd.to_datetime(df_patient['admission_date'],format="mixed")

df_medical.drop_duplicates(subset='patient_id', keep='first', inplace=True)
df_medical['sugar_level'].fillna(df_medical['sugar_level'].median(),inplace=True)
df_medical['bp']=df_medical['bp'].replace({'high':'140/90'})

#'index=False'
df_patient.to_csv('New_patient.csv',index=False)
df_medical.to_csv('New_medical.csv',index=False)

#merge=pd.merge(df_patient,df_medical,on='patient_id',how='outer')
#merge
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   patient_id      130 non-null    object
#  1   name            107 non-null    object
#  2   age             106 non-null    float64
#  3   gender          130 non-null    object
#  4   city            130 non-null    object
#  5   admission_date  130 non-null    object
#  6   height_cm       130 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 7.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   record_id    120 non-null    object
#  1   patient_id   120 non-null    object
#  2   diagnosis    120 non-null    object
#  3   bp           120 non-null    object
#  4   sugar_level  85 non-null     float64
#  5   visit_cost   120 non-null    int64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 5.8+ KB
# C:\Users\sarth\AppData\Local\Temp\ipykernel_10304\767895058.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_patient['age'].fillna(df_patient['age'].median(),inplace=True)
# C:\Users\sarth\AppData\Local\Temp\ipykernel_10304\767895058.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_patient['name'].fillna("Avaish",inplace=True)
# C:\Users\sarth\AppData\Local\Temp\ipykernel_10304\767895058.py:29: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_patient['height_cm'].fillna(df_patient['height_cm'].median(),inplace=True)
# C:\Users\sarth\AppData\Local\Temp\ipykernel_10304\767895058.py:34: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_medical['sugar_level'].fillna(df_medical['sugar_level'].median(),inplace=True)

# %%
df1_medical=pd.read_csv("New_medical.csv")
df1_patient=pd.read_csv("new_patient.csv")
#df1_medical
#df1_patient

# %%
merge=pd.merge(df1_medical,df1_patient,on='patient_id',how='inner')
merge
#merge.to_csv('Merged_records.csv',index=False)
# Out:
#    record_id patient_id     diagnosis      bp  sugar_level  visit_cost  \
# 0       R101       P013  Hypertension  120/80        140.0        2000
# 1       R102       P105      Diabetes  120/80        140.0        2500
# 2       R103       P098  Hypertension  140/90        140.0        3000
# 3       R104       P038        Asthma  140/90        140.0        3000
# 4       R105       P040        Asthma  130/85        140.0        1500
# 5       R106       P033  Hypertension  140/90        140.0        3000
# 6       R107       P034      Diabetes  140/90        180.0        3000
# 7       R108       P027      Diabetes  140/90        140.0        1500
# 8       R109       P100  Hypertension  140/90        110.0        2000
# 9       R110       P090      Diabetes  130/85        140.0        2500
# 10      R111       P051      Diabetes  140/90        110.0        1500
# 11      R112       P089        Asthma  140/90        110.0        1500
# 12      R113       P083  Hypertension  130/85        110.0        2000
# 13      R114       P021      Diabetes  140/90        140.0        2500
# 14      R115       P095        Asthma  140/90        140.0        2500
# 15      R116       P029      Diabetes  140/90        180.0        2500
# 16      R117       P073      Diabetes  120/80        140.0        1500
# 17      R118       P019  Hypertension  140/90        140.0        3000
# 18      R119       P026      Diabetes  140/90        180.0        3000
# 19      R120       P025        Asthma  140/90        140.0        1500
# 20      R122       P107  Hypertension  120/80        180.0        2000
# 21      R126       P068      Diabetes  140/90        140.0        2000
# 22      R127       P045      Diabetes  140/90        140.0        3000
# 23      R128       P084  Hypertension  120/80        140.0        3000
# 24      R129       P046      Diabetes  140/90        180.0        2000
# 25      R130       P055        Asthma  130/85        140.0        2500
# 26      R131       P001      Diabetes  140/90        140.0        2000
# 27      R132       P011      Diabetes  140/90        140.0        3000
# 28      R134       P007  Hypertension  130/85        110.0        2500
# 29      R135       P092  Hypertension  130/85        140.0        1500
# 30      R137       P058      Diabetes  120/80        140.0        2000
# 31      R138       P071        Asthma  130/85        140.0        2000
# 32      R139       P020        Asthma  130/85        140.0        2000
# 33      R140       P035        Asthma  140/90        180.0        3000
# 34      R142       P115      Diabetes  120/80        110.0        1500
# 35      R143       P103      Diabetes  130/85        110.0        2000
# 36      R145       P044        Asthma  120/80        110.0        1500
# 37      R146       P119        Asthma  140/90        140.0        2500
# 38      R148       P101        Asthma  140/90        180.0        2000
# 39      R149       P110        Asthma  120/80        140.0        1500
# 40      R150       P106        Asthma  130/85        110.0        2500
# 41      R151       P067        Asthma  120/80        140.0        1500
# 42      R154       P016        Asthma  140/90        140.0        2500
# 43      R157       P024        Asthma  140/90        180.0        2500
# 44      R159       P006  Hypertension  120/80        140.0        2500
# 45      R160       P039  Hypertension  130/85        110.0        2500
# 46      R161       P002      Diabetes  140/90        180.0        2000
# 47      R167       P076      Diabetes  140/90        140.0        1500
# 48      R169       P086  Hypertension  130/85        140.0        2000
# 49      R172       P052      Diabetes  130/85        140.0        3000
# 50      R173       P003  Hypertension  120/80        180.0        3000
# 51      R174       P077  Hypertension  130/85        140.0        1500
# 52      R175       P030  Hypertension  140/90        180.0        3000
# 53      R176       P010  Hypertension  120/80        110.0        2500
# 54      R177       P116      Diabetes  120/80        140.0        1500
# 55      R180       P117      Diabetes  140/90        140.0        2000
# 56      R181       P054        Asthma  140/90        110.0        2500
# 57      R182       P108        Asthma  130/85        180.0        3000
# 58      R183       P066      Diabetes  140/90        110.0        2000
# 59      R185       P080        Asthma  120/80        140.0        3000
# 60      R186       P063        Asthma  140/90        180.0        2500
# 61      R188       P048      Diabetes  130/85        180.0        2500
# 62      R190       P022        Asthma  140/90        140.0        1500
# 63      R194       P014      Diabetes  120/80        110.0        2000
